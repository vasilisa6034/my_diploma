# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Подмодуль для примитивов
import matplotlib.patches as mpatches

import numpy as np

import math

plt.style.use('default_colors.mplstyle')

# %%
# Пример изображения векторов

fig01 = plt.figure(num=1, figsize=(5, 5))
ax01 = fig01.add_subplot(1, 1, 1)

ax01.set(xlim=(0.5, 5.5), ylim=(0.5, 5.5), aspect='equal')

ax01.set_xticks([])
ax01.set_yticks([])

ax01.plot(3, 1, marker='o', linestyle='None', markersize=5, color='black')
ax01.text(x=2.7, y=0.9, s="O", color='black')

ax01.annotate(text="", xy=(1, 5), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax01.text(x=1.8, y=2.9, s="a", color='r')

ax01.annotate(text="", xy=(4, 4), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax01.text(x=3.3, y=2.5, s="b", color='b')

ax01.annotate(text="", xy=(5, 2), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='g'))
ax01.text(x=3.9, y=1.6, s="c", color='g')
# Out:
# Text(3.9, 1.6, 'c')

# %%
# Ассоциативность векторов

fig02 = plt.figure(num=2, figsize=(5, 5))
ax02 = fig02.add_subplot(1, 1, 1)

ax02.set(xlim=(0.5, 8.5), ylim=(0.5, 9.5), aspect='equal')

ax02.set_xticks([])
ax02.set_yticks([])

ax02.plot(3, 1, marker='o', linestyle='None', markersize=5, color='black')

ax02.annotate(text="", xy=(1, 5), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax02.text(x=1.7, y=2.9, s="a", color='r')

ax02.annotate(text="", xy=(4, 4), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax02.text(x=3.2, y=2.5, s="b", color='b')

ax02.annotate(text="", xy=(2, 8), xytext=(4, 4), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r', 
                                                                 linestyle="--"))

ax02.annotate(text="", xy=(2, 8), xytext=(1, 5), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b', 
                                                                 linestyle="--"))

ax02.annotate(text="", xy=(2, 8), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple'))
ax02.text(x=1.7, y=4.5, s="a+b", color='purple')


ax02.plot(6, 1, marker='o', linestyle='None', markersize=5, color='black')

ax02.annotate(text="", xy=(5, 8), xytext=(6, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple'))
ax02.text(x=4.7, y=4.5, s="a+b", color='purple')

ax02.annotate(text="", xy=(8, 2), xytext=(6, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='g'))
ax02.text(x=6.8, y=1.6, s="c", color='g')

ax02.annotate(text="", xy=(7, 9), xytext=(8, 2), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple', 
                                                                 linestyle="--"))

ax02.annotate(text="", xy=(7, 9), xytext=(5, 8), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='g', 
                                                                  linestyle="--"))

ax02.annotate(text="", xy=(7, 9), xytext=(6, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='brown'))
ax02.text(x=5.4, y=7, s="a+b+c", color='brown')
# Out:
# Text(5.4, 7, 'a+b+c')

# %%
fig02 = plt.figure(num=2, figsize=(5, 5))
ax02 = fig02.add_subplot(1, 1, 1)

ax02.set(xlim=(2.5, 12.5), ylim=(0.5, 9.5), aspect='equal')

ax02.set_xticks([])
ax02.set_yticks([])

ax02.plot(3, 1, marker='o', linestyle='None', markersize=5, color='black')

ax02.annotate(text="", xy=(4, 4), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax02.text(x=3.2, y=2.5, s="b", color='b')

ax02.annotate(text="", xy=(5, 2), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='g'))
ax02.text(x=3.9, y=1.6, s="c", color='g')

ax02.annotate(text="", xy=(6, 5), xytext=(5, 2), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b', 
                                                                 linestyle="--"))

ax02.annotate(text="", xy=(6, 5), xytext=(4, 4), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='g', 
                                                                 linestyle="--"))

ax02.annotate(text="", xy=(6, 5), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax02.text(x=4.1, y=3.6, s="b+c", color='black')


ax02.plot(9, 1, marker='o', linestyle='None', markersize=5, color='black')

ax02.annotate(text="", xy=(7, 5), xytext=(9, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax02.text(x=7.7, y=2.9, s="a", color='r')

ax02.annotate(text="", xy=(12, 5), xytext=(9, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax02.text(x=10.6, y=2.8, s="b+c", color='black')

ax02.annotate(text="", xy=(10, 9), xytext=(12, 5), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r', 
                                                                 linestyle="--"))

ax02.annotate(text="", xy=(10, 9), xytext=(7, 5), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black', 
                                                                  linestyle="--"))

ax02.annotate(text="", xy=(10, 9), xytext=(9, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='brown'))
ax02.text(x=8.2, y=5.5, s="a+b+c", color='brown')
# Out:
# Text(8.2, 5.5, 'a+b+c')

# %%
# Нейтральный вектор по сложению

fig03 = plt.figure(num=3, figsize=(5, 5))
ax03 = fig03.add_subplot(1, 1, 1)

ax03.set(xlim=(0.5, 3), ylim=(0.5, 4.4), aspect='equal')

ax03.set_xticks([])
ax03.set_yticks([])

ax03.plot(2.5, 1, marker='o', linestyle='None', markersize=5, color='black')
ax03.text(x=2.3, y=0.9, s="O", color='black')

ax03.annotate(text="", xy=(1, 4), xytext=(2.5, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax03.text(x=1.8, y=2.5, s="a+0", color='black')
# Out:
# Text(1.8, 2.5, 'a+0')

# %%
# Обратный вектор по сложению

fig04 = plt.figure(num=4, figsize=(5, 5))
ax04 = fig04.add_subplot(1, 1, 1)

ax04.set(xlim=(0.5, 4.5), ylim=(0, 2), aspect='equal')

ax04.set_xticks([])
ax04.set_yticks([])

ax04.plot(2.5, 1, marker='o', linestyle='None', markersize=5, color='black')
ax04.text(x=2.3, y=0.8, s="O", color='black')

ax04.annotate(text="", xy=(1, 1.5), xytext=(2.5, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax04.text(x=1.75, y=1.35, s="a", color='r')

ax04.annotate(text="", xy=(4, 0.5), xytext=(2.5, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax04.text(x=3, y=0.6, s="-a", color='black')
# Out:
# Text(3, 0.6, '-a')

# %%
# Коммутативность векторов по сложению

fig05 = plt.figure(num=5, figsize=(5, 5))
ax05 = fig05.add_subplot(1, 1, 1)

ax05.set(xlim=(0.5, 8.5), ylim=(0.5, 8.5), aspect='equal')

ax05.set_xticks([])
ax05.set_yticks([])

ax05.plot(3, 1, marker='o', linestyle='None', markersize=5, color='black')

ax05.annotate(text="", xy=(1, 5), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax05.text(x=1.7, y=2.9, s="a", color='r')

ax05.annotate(text="", xy=(4, 4), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax05.text(x=3.2, y=2.5, s="b", color='b')

ax05.annotate(text="", xy=(2, 8), xytext=(1, 5), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b', 
                                                                 linestyle="--"))

ax05.annotate(text="", xy=(2, 8), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple'))
ax05.text(x=1.8, y=4.5, s="a+b", color='purple')


ax05.plot(7, 1, marker='o', linestyle='None', markersize=5, color='black')

ax05.annotate(text="", xy=(5, 5), xytext=(7, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax05.text(x=5.7, y=2.9, s="a", color='r')

ax05.annotate(text="", xy=(8, 4), xytext=(7, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax05.text(x=7.2, y=2.5, s="b", color='b')

ax05.annotate(text="", xy=(6, 8), xytext=(8, 4), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r', 
                                                                 linestyle="--"))

ax05.annotate(text="", xy=(6, 8), xytext=(7, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple'))
ax05.text(x=5.8, y=4.5, s="b+a", color='purple')
# Out:
# Text(5.8, 4.5, 'b+a')

# %%
# Дистрибутивность векторов по сложению

fig06 = plt.figure(num=6, figsize=(5, 5))
ax06 = fig06.add_subplot(1, 1, 1)

ax06.set(xlim=(0.5, 9.7), ylim=(0.5, 9.9), aspect='equal')

ax06.set_xticks([])
ax06.set_yticks([])

ax06.plot(3, 1, marker='o', linestyle='None', markersize=5, color='black')

ax06.annotate(text="", xy=(1, 5), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax06.text(x=1.7, y=2.9, s="a", color='r')

ax06.annotate(text="", xy=(4, 4), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax06.text(x=3.2, y=2.5, s="b", color='b')

ax06.annotate(text="", xy=(1.8, 9.4), xytext=(3, 1), arrowprops=dict(width=0.7, headwidth=5, headlength=10, color='black'))
ax06.text(x=2, y=8.6, s="α(a+b)", color='black')

ax06.annotate(text="", xy=(2, 8), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple'))
ax06.text(x=1.7, y=4.5, s="a+b", color='purple')


ax06.plot(8, 1, marker='o', linestyle='None', markersize=5, color='black')

ax06.annotate(text="", xy=(5.6, 5.8), xytext=(8, 1), arrowprops=dict(width=0.7, headwidth=5, headlength=10, color='black'))
ax06.text(x=5.4, y=5, s="αa", color='black')

ax06.annotate(text="", xy=(6, 5), xytext=(8, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax06.text(x=6.7, y=2.9, s="a", color='r')

ax06.annotate(text="", xy=(9.2, 4.6), xytext=(8, 1), arrowprops=dict(width=0.7, headwidth=5, headlength=10, color='black'))
ax06.text(x=9.2, y=4.1, s="αb", color='black')

ax06.annotate(text="", xy=(9, 4), xytext=(8, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax06.text(x=8.2, y=2.5, s="b", color='b')

ax06.annotate(text="", xy=(6.8, 9.4), xytext=(8, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='purple'))
ax06.text(x=7.3, y=6.5, s="αa+αb", color='purple')
# Out:
# Text(7.3, 6.5, 'αa+αb')

# %%
# Аффинное пространство на плоскости

fig07 = plt.figure(num=7, figsize=(5, 5))
ax07 = fig07.add_subplot(1, 1, 1)

ax07.set(xlim=(-0.5, 4), ylim=(-0.5, 3), aspect='equal')

ax07.set_xticks([0])
ax07.set_yticks([0])

ax07.annotate(text="", xy=(3.5, 0), xytext=(0, 0), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax07.text(x=3.5, y=-0.2, s="x", color='black')

ax07.annotate(text="", xy=(0, 2.5), xytext=(0, 0), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax07.text(x=-0.2, y=2.5, s="y", color='black')

ax07.plot(0, 0, marker='o', linestyle='None', markersize=5, color='black')
ax07.text(x=-0.2, y=-0.2, s="O", color='black')

ax07.annotate(text="", xy=(3, 2), xytext=(0, 0), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax07.text(x=1.6, y=0.9, s="p=OP", color='r')

ax07.plot(3, 2, marker='o', linestyle='None', markersize=5, color='black')
ax07.text(x=3.1, y=2.1, s="P", color='black')
# Out:
# Text(3.1, 2.1, 'P')

# %%
#

fig08 = plt.figure(num=8, figsize=(5, 5))
ax08 = fig08.add_subplot(1, 1, 1)

ax08.set(xlim=(-0.5, 4), ylim=(-0.5, 3), aspect='equal')

ax08.set_xticks([0])
ax08.set_yticks([0])

ax08.annotate(text="", xy=(3.5, 0), xytext=(0, 0), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax08.text(x=3.5, y=-0.2, s="x", color='black')

ax08.annotate(text="", xy=(0, 2.5), xytext=(0, 0), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax08.text(x=-0.2, y=2.5, s="y", color='black')

ax08.plot(3, 2, marker='o', linestyle='None', markersize=5, color='black')
ax08.text(x=3.1, y=2.1, s="P", color='black')

ax08.annotate(text="", xy=(2, 1), xytext=(3, 2), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax08.text(x=2, y=1.6, s="u=PQ", color='r')

ax08.plot(2, 1, marker='o', linestyle='None', markersize=5, color='black')
ax08.text(x=1.8, y=0.8, s="Q", color='black')
# Out:
# Text(1.8, 0.8, 'Q')

# %%
# Ориентированная площадь

fig01 = plt.figure(num=1, figsize=(5, 5))
ax01 = fig01.add_subplot(1, 1, 1)

ax01.set(xlim=(0.5, 4.5), ylim=(0.5, 2.5), aspect='equal')

ax01.set_xticks([])
ax01.set_yticks([])

ax01.annotate(text="", xy=(1, 1), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax01.text(x=2, y=0.8, s="a", color='r')

ax01.annotate(text="", xy=(2, 2), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax01.text(x=1.3, y=1.5, s="b", color='b')

ax01.annotate(text="", xy=(4, 2), xytext=(2, 2), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))

ax01.annotate(text="", xy=(3, 1), xytext=(4, 2), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))

arc = mpatches.Arc((1, 1), width=1, height=1, theta1=0, theta2=45, color='grey')
ax01.add_patch(arc)
ax01.text(x=1.5, y=1.2, s="θ", color='grey')
# Out:
# Text(1.5, 1.2, 'θ')

# %%
# Ориентированный объем

fig02 = plt.figure(num=2, figsize=(5, 5))
ax02 = fig02.add_subplot(1, 1, 1)

ax02.set(xlim=(0.5, 4.5), ylim=(0.5, 4), aspect='equal')

ax02.set_xticks([])
ax02.set_yticks([])

ax02.annotate(text="", xy=(3, 1), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax02.text(x=1.8, y=0.8, s="a", color='r')

ax02.annotate(text="", xy=(2, 1.5), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b', linestyle='--'))
ax02.text(x=1.4, y=1.4, s="b", color='b')

ax02.annotate(text="", xy=(1, 3), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='g'))
ax02.text(x=0.8, y=2, s="c", color='g')

ax02.plot((2, 4), (1.5, 1.5), color='r', linestyle='--')

ax02.plot((3, 4), (1, 1.5), color='b')

ax02.plot((2, 2), (1.5, 3.5), color='g', linestyle='--')

ax02.plot((4, 4), (3.5, 1.5), color='g')

ax02.plot((3, 3), (1, 3), color='g')

ax02.plot((1, 3), (3, 3), color='r')

ax02.plot((3, 4), (3, 3.5), color='b')

ax02.plot((4, 2), (3.5, 3.5), color='r')

ax02.plot((2, 1), (3.5, 3), color='b')

# %%
# Разложение вектора

fig03 = plt.figure(num=3, figsize=(5, 5))
ax03 = fig03.add_subplot(1, 1, 1)

ax03.set(xlim=(0.5, 3.5), ylim=(0.5, 2.5), aspect='equal')

ax03.set_xticks([])
ax03.set_yticks([])

ax03.annotate(text="", xy=(3, 1), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='r'))
ax03.text(x=2, y=0.85, s="a", color='r')

ax03.annotate(text="", xy=(2, 2), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax03.text(x=1.4, y=1.5, s="v", color='b')

ax03.plot((2, 2), (2, 1), color='grey', linestyle='--')

ax03.annotate(text="", xy=(1, 2), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax03.text(x=0.8, y=1.5, s="v⊥", color='black')

ax03.annotate(text="", xy=(2, 2), xytext=(1, 2), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax03.text(x=1.5, y=2.1, s="v∥", color='black')
# Out:
# Text(1.5, 2.1, 'v∥')

# %%
# Отражение вектора

fig04 = plt.figure(num=4, figsize=(5, 5))
ax04 = fig04.add_subplot(1, 1, 1)

ax04.set(xlim=(0.5, 5.5), ylim=(0.5, 3.5), aspect='equal')

ax04.set_xticks([])
ax04.set_yticks([])

ax04.annotate(text="", xy=(1, 1), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax04.text(x=1.9, y=0.8, s="-v⊥", color='black')

ax04.annotate(text="", xy=(5, 1), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax04.text(x=3.8, y=0.8, s="v⊥", color='black')

ax04.annotate(text="", xy=(3, 3), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='black'))
ax04.text(x=2.7, y=2.5, s="v∥", color='black')

ax04.annotate(text="", xy=(3, 2), xytext=(3, 1), arrowprops=dict(width=0.3, headwidth=5, headlength=10, color='r'))
ax04.text(x=3.1, y=1.5, s="a", color='r')

ax04.annotate(text="", xy=(1, 3), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax04.text(x=1.8, y=1.8, s="v'", color='b')

ax04.annotate(text="", xy=(5, 3), xytext=(3, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='b'))
ax04.text(x=4, y=1.8, s="v", color='b')

ax04.annotate(text="", xy=(1, 3), xytext=(1, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='grey'))
ax04.text(x=1.1, y=1.9, s="v∥", color='grey')

ax04.annotate(text="", xy=(5, 3), xytext=(5, 1), arrowprops=dict(width=0.5, headwidth=5, headlength=10, color='grey'))
ax04.text(x=4.7, y=1.9, s="v∥", color='grey')

ax04.plot((1, 5), (3, 3), color='grey', linestyle='--')
